# %% [markdown]
# ## exploration for data pulled from chicago tattoo artists instagram accounts

# %%
import os
import json
import pandas as pd
from IPython.display import Image
import csv
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# create dictionary from artis/shop .json files

fname = '/Users/kylefrankovich/Desktop/insight_project_data/feralcatbox/feralcatbox.json'
data = json.load(open(fname))
len(data)
# Out:
# 10

# %%
data[3]
# Out:
# {'__typename': 'GraphImage',
#  'comments_disabled': False,
#  'dimensions': {'height': 1080, 'width': 1080},
#  'display_url': 'https://scontent-atl3-1.cdninstagram.com/vp/28607fb4ca62fc1cfe265fecffd76904/5AE6B6C4/t51.2885-15/e35/26066485_169583613655603_4826747482048299008_n.jpg',
#  'edge_media_preview_like': {'count': 8208},
#  'edge_media_to_caption': {'edges': [{'node': {'text': 'The feeling when you’re nearing the end of a backpiece...🙆🏼\u200d♀️😭'}}]},
#  'edge_media_to_comment': {'count': 95},
#  'id': '1688863624193359502',
#  'is_video': False,
#  'location': {'has_public_page': True,
#   'id': '1017368811',
#   'name': 'Black Oak Tattoo',
#   'slug': 'black-oak-tattoo'},
#  'owner': {'id': '13743730'},
#  'shortcode': 'BdwDISqH76O',
#  'tags': [],
#  'taken_at_timestamp': 1515548254,
#  'thumbnail_resources': [{'config_height': 150,
#    'config_width': 150,
#    'src': 'https://scontent-atl3-1.cdninstagram.com/vp/b2cf59e42e5e59e7815b27b15f9077a0/5AFEDBA1/t51.2885-15/s150x150/e35/26066485_169583613655603_4826747482048299008_n.jpg'},
#   {'config_height': 240,
#    'config_width': 240,
#    'src': 'https://scontent-atl3-1.cdninstagram.com/vp/231fb8fd8d1e2babe9c10b2a459b0888/5AF7A89E/t51.2885-15/s240x240/e35/26066485_169583613655603_4826747482048299008_n.jpg'},
#   {'config_height': 320,
#    'config_width': 320,
#    'src': 'https://scontent-atl3-1.cdninstagram.com/vp/76a670ce627f89401731188606397b3c/5AFF12E6/t51.2885-15/s320x320/e35/26066485_169583613655603_4826747482048299008_n.jpg'},
#   {'config_height': 480,
#    'config_width': 480,
#    'src': 'https://scontent-atl3-1.cdninstagram.com/vp/c0212540d07534ba24bd159a85004779/5AFA4360/t51.2885-15/s480x480/e35/26066485_169583613655603_4826747482048299008_n.jpg'},
#   {'config_height': 640,
#    'config_width': 640,
#    'src': 'https://scontent-atl3-1.cdninstagram.com/vp/430b6118a01341e1e737fab08aa8a07b/5AF8DAA5/t51.2885-15/s640x640/sh0.08/e35/26066485_169583613655603_4826747482048299008_n.jpg'}],
#  'thumbnail_src': 'https://scontent-atl3-1.cdninstagram.com/vp/430b6118a01341e1e737fab08aa8a07b/5AF8DAA5/t51.2885-15/s640x640/sh0.08/e35/26066485_169583613655603_4826747482048299008_n.jpg',
#  'urls': ['https://scontent-atl3-1.cdninstagram.com/vp/28607fb4ca62fc1cfe265fecffd76904/5AE6B6C4/t51.2885-15/e35/26066485_169583613655603_4826747482048299008_n.jpg']}

# %%
i = 9
print('artist:', )
print('image URL:',data[i]['display_url'])
print('number of likes:', data[i]['edge_media_preview_like']['count'])
print('caption:', data[i]['edge_media_to_caption']['edges'][0]['node']['text'])
print('tags:',data[i]['tags'])
print('shortcode:',data[i]['shortcode'])
Image(data[i]['display_url'], width=600)
# Out:
# artist:
# image URL: https://scontent-atl3-1.cdninstagram.com/vp/af0670681778884d6b6f274be553a122/5AF8D57F/t51.2885-15/e35/25013352_209067759660438_8446239352941445120_n.jpg
# number of likes: 3993
# caption: Last tattoo of the year / but holy shit, this year. (Redouté rosa berberifolia for Cara. Swipe for video and bonus wrist petal.)
# tags: []
# shortcode: BdBw9CWn2EV

# %%
# https://www.instagram.com/p/BeBwOoND4Cc/
insta_url = 'https://www.instagram.com/p/'
data[i]['shortcode']
insta_url + data[i]['shortcode']
# Out:
# 'https://www.instagram.com/p/BeBky6Slc67'

# %%
rootdir = '/Users/kylefrankovich/Desktop/insight_project_data'

rows_list = []
insta_url = 'https://www.instagram.com/p/'

for root, dirs, files in os.walk(rootdir):
    for file in files:
        if file.endswith('.json'):
            current_account_data = json.load(open(os.path.join(root, file))) # load current account .json (shop or artist)
            account_name = os.path.basename(root)
            for post in current_account_data: # loop throough all posts for account
                temp_dict = {}
                temp_dict['account'] = account_name
                temp_dict['URL'] = post['display_url']
                temp_dict['link_to_post'] = insta_url + post['shortcode']
                temp_dict['likes'] = post['edge_media_preview_like']['count']
                if 'tags' in post.keys():
                    temp_dict['tags'] = post['tags']
                else:
                    temp_dict['tags'] = []
                if post['edge_media_to_caption']['edges']:
                    temp_dict['caption'] = post['edge_media_to_caption']['edges'][0]['node']['text']
                else: 
                    temp_dict['caption'] = 'no caption'
                
                rows_list.append(temp_dict)

df = pd.DataFrame(rows_list)

# %%
print('number of images:',len(df))
print('number of unique accounts:',len(df['account'].unique()))
print('most likes:', max(df['likes']))
# Out:
# number of images: 2288
# number of unique accounts: 231
# most likes: 656460

# %%
df.describe()
# Out:
#                likes
# count    2288.000000
# mean     2477.489510
# std     29445.539446
# min         3.000000
# 25%        54.000000
# 50%       100.000000
# 75%       219.000000
# max    656460.000000

# %%
top_posts = df.sort_values(by='likes', ascending=False).head(50)
top_posts
# Out:
#                                                     URL          account  \
# 1633  https://scontent-atl3-1.cdninstagram.com/vp/88...           g_eazy
# 1748  https://scontent-atl3-1.cdninstagram.com/vp/97...           marvel
# 1636  https://scontent-atl3-1.cdninstagram.com/vp/80...           g_eazy
# 1632  https://scontent-atl3-1.cdninstagram.com/vp/cd...           g_eazy
# 1639  https://scontent-atl3-1.cdninstagram.com/vp/e5...           g_eazy
# 1634  https://scontent-atl3-1.cdninstagram.com/vp/2f...           g_eazy
# 1638  https://scontent-atl3-1.cdninstagram.com/vp/14...           g_eazy
# 1403  https://www.instagram.com/p/BeD2DAYj8_W
# 289   https://www.instagram.com/p/BdxzrjllNWx
# 1190  https://www.instagram.com/p/BdjSetjgTkK
# 125   https://www.instagram.com/p/BeA7W7KlS74
# 1811  https://www.instagram.com/p/Bch9EA5jSQS
# 862   https://www.instagram.com/p/Bd6ZUDQH7Wr
# 284   https://www.instagram.com/p/Bd-4RJMFOPj
# 822   https://www.instagram.com/p/BeFn6o-lYD7
# 290   https://www.instagram.com/p/BdvM9wflr6R
# 3     https://www.instagram.com/p/Bd1YOszA4QI
#
#                                                    tags
# 1633                                                 []
# 1748                                 [AntManAndTheWasp]
# 1636                                                 []
# 1632                                                 []
# 1639                                                 []
# 1634                                                 []
# 1638                                                 []
# 1637                                                 []
# 1630                                      [DiveBarTour]
# 1631                                                 []
# 1635           [SuiWenjing, HanCong, AboveTheNoise, Ad]
# 1745                                     [BlackPanther]
# 1743                                                 []
# 1747                                   [CaptainAmerica]
# 1746                                     [BlackPanther]
# 1741                                                 []
# 1744                         [BelatedNCBD, MarvelStack]
# 1742                                                 []
# 1740                                                 []
# 124   [tattooed, reptiles, dinosaurs, book, tattoo, ...
# 287                                                  []
# 1739                                                 []
# 1854  [alchemisttattoo, tattoos, self135, pixels, ta...
# 1402  [sullenangels, sullenclothing, sullenfamily, t...
# 1174  [loveyall, flowerlove, ladytattooers, thankyou...
# 864                                                  []
# 129   [books, book, artistic, skull, illustration, c...
# 128                           [tattooed, books, tattoo]
# 1407  [sullenclothing, freehand, blackouttattoo, tog...
# 286                                       [WinterBloom]
# 1856  [tattoos, band, rosetattoo, chain, flowertatto...
# 288                                                  []
# 1199                                             [2018]
# 285                          [WinterBloom, FloralChill]
# 127   [Flashback, painters, book, video, portrait, p...
# 827   [tatuaje, tattoos, ink, realistictattoo, tatto...
# 1182                                                 []
# 1409  [sullenclothing, Scratchy, Itchy, togetherweri...
# 865                                                  []
# 830   [tatuaje, тату, tatuaggi, タトゥーo, realistic, bl...
# 1403         [togetherwerise, sullenclothing, sullentv]
# 289                                                  []
# 1190                                                 []
# 125                               [skull, illustration]
# 1811                                   [ReadyPlayerOne]
# 862                           [maketattooingscaryagain]
# 284                                                  []
# 822   [tatuaje, tattoos, ink, realistictattoo, tatto...
# 290                                                  []
# 3     [chicagoartist, illustration, ghost, darkart, ...

# %%
print(top_posts.iloc[0]['link_to_post']) # JT and Busta
# Out:
# https://www.instagram.com/p/Bd9Rtv-n6Bg

# %%
accounts_to_filter = ['g_eazy', 'marvel', 'popsockets',
                     'readyplayerone', 'junkyardchicago']

# %%
df_filtered = df.loc[~df['account'].isin(accounts_to_filter)]

# %%
len(df_filtered)
# Out:
# 2240

# %%
print('number of images:',len(df_filtered))
print('number of unique accounts:',len(df_filtered['account'].unique()))
print('most likes:', max(df_filtered['likes']))
# Out:
# number of images: 2240
# number of unique accounts: 226
# most likes: 13332

# %%
top_posts_filtered = df_filtered.sort_values(by='likes', ascending=False).head(30)

# %%
top_posts_filtered.head()
# Out:
#                                                     URL         account  \
# 124   https://scontent-atl3-1.cdninstagram.com/vp/b5...  outofstepbooks
# 1854  https://scontent-atl3-1.cdninstagram.com/vp/96...      tattoosnob
# 1402  https://scontent-atl3-1.cdninstagram.com/vp/69...        sullentv
# 1174  https://scontent-atl3-1.cdninstagram.com/vp/b1...    katietattoos
# 864   https://scontent-atl3-1.cdninstagram.com/vp/28...     feralcatbox
#
#                                                 caption  likes  \
# 124   Incredible placement and execution on this #sn...  13332
# 1854  Pixelated Nipples by @self135 at Alchemist Tat...  11018
# 1402  #HumpDay vibes with @teneile_napoli!\n#sullent...  10453
# 1174  In honor of the Ink Master season 9 finale re-...   8256
# 864   The feeling when you’re nearing the end of a b...   8208
#
#                                  link_to_post  \
# 124   https://www.instagram.com/p/BeB56DIFm_j
# 1854  https://www.instagram.com/p/BeEpHLlnYI0
# 1402  https://www.instagram.com/p/BeEeyggD9YO
# 1174  https://www.instagram.com/p/BdwMwOkHDFD
# 864   https://www.instagram.com/p/BdwDISqH76O
#
#                                                    tags
# 124   [tattooed, reptiles, dinosaurs, book, tattoo, ...
# 1854  [alchemisttattoo, tattoos, self135, pixels, ta...
# 1402  [sullenangels, sullenclothing, sullenfamily, t...
# 1174  [loveyall, flowerlove, ladytattooers, thankyou...
# 864                                                  []

# %%
# top_posts_filtered.iloc[0]['URL']
Image(top_posts_filtered.iloc[28]['URL'], width=600)

# %% [markdown]
# ### data exploration:

# %%
# histogram of likes, unfiltered dataset:

sns.distplot(df["likes"])

# %%
# histogram of likes, filtered dataset:

sns.distplot(df_filtered[df_filtered.likes < 2000]['likes'])

# %%
# word cloud plot for hashtags:

hashtags = []
list_of_tags = list(df_filtered['tags'])
for post in list_of_tags:
    for i in post:
        hashtags.append(i)

# %%
hashtag_string = ' '.join(hashtags)

#Create the wordcloud object
wordcloud = WordCloud(width=800, height=800, margin=0).generate(hashtag_string)

# Display the generated image:

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
# Set figure width to 12 and height to 9
fig_size[0] = 12
fig_size[1] = 9
plt.rcParams["figure.figsize"] = fig_size
plt.show()

# %%
likes_by_account = df_filtered.groupby(['account'])['likes'].sum()
likes_by_account.sort_values(ascending=False)[0:10]
# Out:
# account
# outofstepbooks    49045
# sullentv          41455
# feralcatbox       40137
# tattoosnob        34962
# realistic.ink     34022
# butterstinker     23791
# katietattoos      23295
# jrdiaz16          17502
# bvla              15888
# fieldmuseum       15035
# Name: likes, dtype: int64

# %%
# top ten accounts/artists:
top_accounts = likes_by_account.sort_values(ascending=False)[0:10]
names = top_accounts.index
names

# sns.set_style("whitegrid")

ax = sns.barplot(x=names, y=top_accounts, data=top_accounts)

# %%
images = []
for img_path in glob.glob('presentation_images/*.jpg'):
    images.append(mpimg.imread(img_path))

plt.figure(figsize=(20,20))
columns = 5
for i, image in enumerate(images):
    plt.subplot(len(images) / columns + 1, columns, i + 1)
    plt.axis('off')
    plt.imshow(image)
