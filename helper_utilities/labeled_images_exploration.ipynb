# %% [markdown]
# ### labeled image data exploration

# %%
import os
import matplotlib.pyplot as plt
import glob
import matplotlib.image as mpimg
import numpy as np
from IPython.display import Image
import pandas as pd
import json
import seaborn as sns
# %matplotlib inline

# %%
image_dir = '/Users/kylefrankovich/Desktop/insight_training_data'
image_list = []
for dir, subdir, files in os.walk(image_dir):
    for file in files:
        image_list.append(os.path.join(dir, file))
len(image_list)
# Out:
# 4019

# %%
len(image_list) != len(set(image_list)) # no duplicates in training data
# Out:
# False

# %%
img=mpimg.imread(image_list[0])
plt.imshow(img)

# %%
tattoo_training_labels_df = pd.read_csv('/Users/kylefrankovich/Desktop/insight_training_data/tattoo_training_image_labels.csv')
number_of_tattoo_images = len(tattoo_training_labels_df[tattoo_training_labels_df['category'] == 1])
number_of_non_tattoo_images = len(tattoo_training_labels_df[tattoo_training_labels_df['category'] == 0])
print('total labeled images:', len(tattoo_training_labels_df))
print('number of labeled tattoos:', number_of_tattoo_images)
print('number of labeled non-tattoo:', number_of_non_tattoo_images)
# Out:
# total labeled images: 2306
# number of labeled tattoos: 1000
# number of labeled non-tattoo: 1306

# %%
tattoo_training_labels_df.head()
# Out:
#                                            file_name  category
# 0  /Users/kylefrankovich/Desktop/insight_training...         0
# 1  /Users/kylefrankovich/Desktop/insight_training...         0
# 2  /Users/kylefrankovich/Desktop/insight_training...         0
# 3  /Users/kylefrankovich/Desktop/insight_training...         0
# 4  /Users/kylefrankovich/Desktop/insight_training...         1

# %%
Image('/Users/kylefrankovich/Desktop/insight_training_data/26154289_208279443082285_8967196341662908416_n.jpg')

# %%
# load training data json file:
training_data = json.load(open('/Users/kylefrankovich/Desktop/insight_training_data/tattoo.json'))
len(training_data)
training_data[2]
# Out:
# {'dimensions': {'height': 1080, 'width': 1080},
#  'display_url': 'https://scontent-atl3-1.cdninstagram.com/vp/d03d17e6e91d5c49db3e4df07b2b1ba7/5AD9848F/t51.2885-15/e35/26073555_398979743886755_2817757807581855744_n.jpg',
#  'edge_liked_by': {'count': 502},
#  'edge_media_to_caption': {'edges': [{'node': {'text': '• LEVITATE •\n.\n.\n.\n.\n.\n#nature #multiliner #micron #fineliner #blackandwilustrationhite #ink #inkonpaper #tattoo #inked #pen #art #design #inkfeature #instafineliner #blackworknow #linework #tempuradesign #iblackwork #thedesignfix #sketchbook #blackandwhite #sketch #sketchbook #wonderlust #ocean #sea #wave #mantaray #graphicroozane'}}]},
#  'edge_media_to_comment': {'count': 9},
#  'id': '1694385452478862645',
#  'is_video': False,
#  'location': None,
#  'owner': {'id': '4756799117'},
#  'shortcode': 'BeDqpd_l5U1',
#  'tags': ['graphicroozane',
#   'ink',
#   'inkonpaper',
#   'blackworknow',
#   'wave',
#   'multiliner',
#   'inked',
#   'blackandwilustrationhite',
# ...

# %%
search_image = '/Users/kylefrankovich/Desktop/insight_training_data/26154289_208279443082285_8967196341662908416_n.jpg'
search_image[-10:]
# Out:
# '8416_n.jpg'

# %%
i = 14

# %%
print(blah.iloc[i]['category'])
Image(blah.iloc[i]['file_name'])
# Out:
# 1

# %%
# get list of files within a directory:

image_dir = '/Users/kylefrankovich/Desktop/cats_dogs'
labeled_image_names = []
for dir, subdir, files in os.walk(image_dir):
    for file in files:
        if file.endswith('.jpg'):
            labeled_image_names.append(os.path.join(dir, file))
len(labeled_image_names)
# Out:
# 35

# %%
labeled_image_names
# Out:
# ['/Users/kylefrankovich/Desktop/cats_dogs/1010904-poochie.gif.jpg',
#  '/Users/kylefrankovich/Desktop/cats_dogs/6_cat.jpg',
#  '/Users/kylefrankovich/Desktop/cats_dogs/12_dog.jpg',
#  '/Users/kylefrankovich/Desktop/cats_dogs/1_dog.jpg',
#  '/Users/kylefrankovich/Desktop/cats_dogs/7_cat.jpg',
#  '/Users/kylefrankovich/Desktop/cats_dogs/13_dog.jpg',
#  '/Users/kylefrankovich/Desktop/cats_dogs/14_copy_dog.jpg',
#  '/Users/kylefrankovich/Desktop/cats_dogs/giphy-facebook_s copy.jpg',
#  '/Users/kylefrankovich/Desktop/cats_dogs/18_dog.jpg',
#  '/Users/kylefrankovich/Desktop/cats_dogs/5_cat.jpg',
#  '/Users/kylefrankovich/Desktop/cats_dogs/2_dog.jpg',
#  '/Users/kylefrankovich/Desktop/cats_dogs/11_dog.jpg',
#  '/Users/kylefrankovich/Desktop/cats_dogs/8_copy_cat.jpg',
#  '/Users/kylefrankovich/Desktop/cats_dogs/4_cat.jpg',
#  '/Users/kylefrankovich/Desktop/cats_dogs/3_dog.jpg',
#  '/Users/kylefrankovich/Desktop/cats_dogs/images_cat_copy.jpg',
# ...

# %%
files_to_copy = labeled_image_names[0:5]
files_to_copy
# Out:
# ['/Users/kylefrankovich/Desktop/cats_dogs/1010904-poochie.gif.jpg',
#  '/Users/kylefrankovich/Desktop/cats_dogs/6_cat.jpg',
#  '/Users/kylefrankovich/Desktop/cats_dogs/12_dog.jpg',
#  '/Users/kylefrankovich/Desktop/cats_dogs/1_dog.jpg',
#  '/Users/kylefrankovich/Desktop/cats_dogs/7_cat.jpg']

# %%
# moving a list of files to a new directory:

# cp `cat list.txt` new_folder

# cp `cat /Users/kylefrankovich/Desktop/cats_dogs/files_to_move.csv` '/Users/kylefrankovich/Desktop/cats_dogs/file_copies'

csv_output_file = '/Users/kylefrankovich/Desktop/cats_dogs/files_to_move.csv'

new_folder = '/Users/kylefrankovich/Desktop/cats_dogs/file_copies'

#Assuming res is a flat list
with open(csv_output_file, "w") as output:
    writer = csv.writer(output, lineterminator='\n')
    for val in files_to_copy:
        writer.writerow([val])

# %%
cats_dogs_df = pd.read_csv('/Users/kylefrankovich/Desktop/cats_dogs/cat_dog_image_labels.csv')
cats_dogs_df['category'].sum() # 24 dogs
# Out:
# 24

# %%
len(cats_dogs_df[cats_dogs_df['category'] == 1])
# Out:
# 24

# %%
sns.set_style("darkgrid")
plt.plot(np.cumsum(np.random.randn(1000,1)))
plt.show()

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sales = [{'account': 'Jones LLC', 'Jan': 150, 'Feb': 200, 'Mar': 140},
         {'account': 'Alpha Co',  'Jan': 200, 'Feb': 210, 'Mar': 215},
         {'account': 'Blue Inc',  'Jan': 50,  'Feb': 90,  'Mar': 95 }]

blah = [{'week': '1', 'number_of_tabs': 24},
       {'week': '2','number_of_tabs': 67},
       {'week': '3','number_of_tabs': 184}]
sales_df = pd.DataFrame(sales)
blah_df = pd.DataFrame(blah)
blah_df
# Out:
#    number_of_tabs week
# 0              24    1
# 1              67    2
# 2             184    3

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
ax = sns.pointplot(x="time", y="total_bill", data=tips)

# %%
ax = sns.pointplot(x="week", y="number_of_tabs", data=blah_df).set_title('number of tabs open as function of time in insight')
